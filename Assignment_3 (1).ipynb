# %%
#Practical Question
#Q1. Write a code to create a string with your name and print it.
string = "Tanushree Jaiswal"
print(string)
# Out:
# Tanushree Jaiswal

# %%
#Q2. Write a code to find the length of the string "Hello World"
string = "Hello World"
len(string)
# Out:
# 11

# %%
#Q3. Write a code to slice the first 3 characters from the string "Python Programming"
string = "Python Programming"
string[0:3]
# Out:
# 'Pyt'

# %%
#Q4. Write a code to convert the string "hello" to uppercase
string = "hello"
string.upper()
# Out:
# 'HELLO'

# %%
#Q5. Write a code to replace the word "apple" with "orange" in the string "I like apple"
string = " I like apple"
string.replace("apple","orange")
# Out:
# ' I like orange'

# %%
#Q6. Write a code to create a list with numbers 1 to 5 and print it.
list = [1,2,3,4,5]
print(list)
# Out:
# [1, 2, 3, 4, 5]

# %%
#Q7. Write a code to append the number 10 to the list [1, 2, 3, 4].
list = [1,2,3,4]
list.append(10)
print(list)
# Out:
# [1, 2, 3, 4, 10]

# %%
#Q8. Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]
list = [1,2,3,4,5]
list.remove(3)
print (list)
# Out:
# [1, 2, 4, 5]

# %%
#Q9. Write a code to access the second element in the list ['a', 'b', 'c', 'd']
list = ['a', 'b', 'c', 'd']
print(list[1])
# Out:
# b

# %%
#Q10 Write a code to reverse the list [10, 20, 30, 40, 50].
list = [10, 20, 30, 40, 50]
list.reverse()
print(list)
# Out:
# [50, 40, 30, 20, 10]

# %%
#Q11. Write a code to create a tuple with the elements 100, 200, 300 and print it.
t = (100,200,300)
print(t)
# Out:
# (100, 200, 300)

# %%
#Q12. Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow')
t = ('red', 'green', 'blue', 'yellow')
print(t[1:])
# Out:
# ('green', 'blue', 'yellow')

# %%
#Q13. Write a code to find the minimum number in the tuple (10, 20, 5, 15).
t = (10, 20, 5, 15)
print(min(t))
# Out:
# 5

# %%
#Q14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
t = ('dog', 'cat', 'rabbit')
t.index('cat')
# Out:
# 1

# %%
#Q15. Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.
t = ('apple','kiwi','banana')
print(t)
'kiwi' in t

# %%
#Q16. Write a code to create a set with the elements 'a', 'b', 'c' and print it
s = {'a','b','c'}
print(s)
# Out:
# {'b', 'a', 'c'}

# %%
#Q17. Write a code to clear all elements from the set {1, 2, 3, 4, 5}.
s = {1, 2, 3, 4, 5}
s.clear()
print(s)
# Out:
# set()

# %%
#Q18. Write a code to remove the element 4 from the set {1, 2, 3, 4.
s = {1,2,3,4}
s.remove(4)
print(s)
# Out:
# {1, 2, 3}

# %%
#Q19. Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.
s1 = {1,2,3}
s2 = {3,4,5}
print(s1 | s2)
# Out:
# {1, 2, 3, 4, 5}

# %%
#Q20. Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}.
s1 = {1,2,3}
s2 = {2,3,4,}
print(s1 & s2)
# Out:
# {2, 3}

# %%
#Q21. Write a code to create a dictionary with the keys "name", "age", and "city", and print it.
d = {"name":'Tanushree',"age":23,"city":'varanasi'}
print(d)
# Out:
# {'name': 'Tanushree', 'age': 23, 'city': 'varanasi'}

# %%
#Q22. Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.
d1 = {'name': 'John', 'age': 25}
d2 = {"country": "USA"}
d1.update(d2)
print(d1)
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
#Q23. Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}.
d = {'name': 'Alice', 'age': 30}
print(d['name'])
# Out:
# Alice

# %%
#Q24. Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.
d = {'name': 'Bob', 'age': 22, 'city': 'New York'}
del d['age']
print(d)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
#Q25. Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}.
d = {'name': 'Alice', 'city': 'Paris'}
'city' in d
# Out:
# True

# %%
#Q26. Write a code to create a list, a tuple, and a dictionary, and print them all.
list = [1,2.2,'Tanu',28]
t = ('apple','banana','mango')
d = {"name":"Tanu","age":23}
print(list)
print(t)
print(d)
# Out:
# [1, 2.2, 'Tanu', 28]
# ('apple', 'banana', 'mango')
# {'name': 'Tanu', 'age': 23}

# %%
#Q27. Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result.(replaced)
import random
list = [random.randint(1,100) for i in range(5)]
list=sorted(list)
print(list)
# Out:
# [10, 14, 17, 19, 54]

# %%
#Q28. Write a code to create a list with strings and print the element at the third index.
list = ['Tanushree','Krishna','Nitu','Sanjay','Kritarth']
print(list[3])
# Out:
# Sanjay

# %%
#Q29. Write a code to combine two dictionaries into one and print the result
d1 = {'name': 'John', 'age': 25}
d2 = {'course':'Data Science','duration':6}
d1.update(d2)
print(d1)
# Out:
# {'name': 'John', 'age': 25, 'course': 'Data Science', 'duration': 6}

# %%
#Q30. Write a code to convert a list of strings into a set.
list = ['Tanushree','Sanjay','Nitu','Khushi','Nitu','Krishna']
list = set(list)
print(list)
# Out:
# {'Krishna', 'Sanjay', 'Nitu', 'Khushi', 'Tanushree'}

# %%
#THEORY QUESTION 
#Q1. What are data structures, and why are they important.
#Ans: Data structures are ways to organize and store data in a computer. They are important because they help you store, retrieve, and process data efficiently

# %%
#Q2. Explain the difference between mutable and immutable data types with examples
#Ans: Mutable data types can be changed after they are created, while immutable data types cannot be changed after created.

# %%
#Q3.  What are the main differences between lists and tuples in Python
#Ans: n Python, the main differences between lists and tuples are that lists are mutable, while tuples are immutable. Tuples are also more memory efficient and faster than lists.

# %%
#Q4. Describe how dictionaries store data
#Ans: Dictionaries are used to store data values in key:value pairs. A dictionary is a collection which is ordered*, changeable and do not allow duplicates.

# %%
#Q5. Why might you use a set instead of a list in Python
#Ans: Sets are highly useful to efficiently remove duplicate values from a collection like a list and to perform common math operations like unions and intersections.

# %%
#Q6. What is a string in Python, and how is it different from a list
#Ans: a string is a sequence of characters enclosed in quotes (single or double), representing textual data, while a list is an ordered collection of items (which can be different data types like numbers, strings, etc.) enclosed in square brackets.

# %%
#Q7. How do tuples ensure data integrity in Python
#Ans: Tuples are immutable to ensure that their contents remain constant throughout their lifecycle, guaranteeing data integrity and reliability.

# %%
#Q8. What is a hash table, and how does it relate to dictionaries in Python
#Ans: a hash table is a data structure that's implemented using the Dictionary data type. Hash tables are used to store key-value pairs, and they make it easy and fast to access data

# %%
#Q9. Can lists contain different data types in Python
#Ans: Yes, lists can contain heterogeneous data types and objects

# %%
#Q10. Explain why strings are immutable in Python
#Ans: Strings in Python are “immutable” which means they can not be changed after they are created.

# %%
#Q11. What advantages do dictionaries offer over lists for certain tasks
#Ans: Dictionaries are faster than lists for tasks that involve searching for items, or looking up values. Dictionaries are also more flexible and can store more complex data structures

# %%
#Q12. Describe a scenario where using a tuple would be preferable over a list
#Ans: Use a tuple if you need an immutable collection where the elements won't change after creation. Example: for employee id which is unique.

# %%
##Q13. How do sets handle duplicate values in Python3
#Ans: Items of a set in python are immutable (unchangeable), do not duplicate values, and unordered. Thus, items in a set do not appear in a stipulated manner, i.e., they can appear in a different order every time it is used.

# %%
#Q14. How does the “in” keyword work differently for lists and dictionaries.
#Ans: The "in" operator works on dictionaries; it tells you whether something appears or not as a key in the dictionary. It returns two values True or False.

# %%
#Q15. Can you modify the elements of a tuple? Explain why or why not.
#Ans: No, you cannot modify the elements of a tuple in Python because tuples are immutable.

# %%
#Q16. What is a nested dictionary, and give an example of its use case.
#Ans: A nested dictionary is a dictionary that is stored inside another dictionary. It's a way to organize data into layers

# %%
#Q17. Describe the time complexity of accessing elements in a dictionary.
#Ans: Python dictionaries use a hashing system that allows them to quickly look up keys.

# %%
#Q18.  In what situations are lists preferred over dictionaries.
#Ans: For quick data look-ups, configurations, or caches, favor dictionaries. For ordered collections and sequence operations, such as maintaining a stack or queue, lists are more suitable.

# %%
#Q19. Why are dictionaries considered unordered, and how does that affect data retrieval.
#Ans: A dictionary is termed an unordered collection of objects because dictionaries do not maintain any inherent order of the items based on when they were added

# %%
#Q20. Explain the difference between a list and a dictionary in terms of data retrieval
#Ans: the difference between a list and a dictionary in terms of data retrieval is that lists use indices to access elements, while dictionaries use keys.
